# %%
import pandas

# %%
df = pandas.read_csv("supermarkets/supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df = pandas.read_json("supermarkets/supermarkets.json")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df = pandas.read_excel("supermarkets/supermarkets.xlsx", sheet_name=0)
df
# Out:
#    ID          Address           City             State Country  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA
#
#   Supermarket Name  Number of Employees
# 0          Madeira                    8
# 1      Bready Shop                   15
# 2      Super River                   25
# 3       Ben's Shop                   10
# 4          Sanchez                   12
# 5       Richvalley                   20

# %%
df = pandas.read_csv("supermarkets/supermarkets-commas.txt")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df = pandas.read_csv("supermarkets/supermarkets-semi-colons.txt", delimiter=';')
df
# Out:
#    ID          Address           City             State Country          Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA       Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA   Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA       Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA    Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df = pandas.read_csv("supermarkets/supermarkets.csv", header=None, skiprows=1)
df
# Out:
#    0                1              2                 3    4            5   6
# 0  1     3666 21st St  San Francisco          CA 94114  USA      Madeira   8
# 1  2   735 Dolores St  San Francisco          CA 94119  USA  Bready Shop  15
# 2  3      332 Hill St  San Francisco  California 94114  USA  Super River  25
# 3  4     3995 23rd St  San Francisco          CA 94114  USA   Ben's Shop  10
# 4  5  1056 Sanchez St  San Francisco        California  USA      Sanchez  12
# 5  6  551 Alvarado St  San Francisco          CA 94114  USA   Richvalley  20

# %%
df.columns = ["ID", "Address", "City", "State", "Country", "Name", "Employees"]
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
pandas.read_csv?

# %%
df.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df.set_index("Address", inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-278ab8046479> in <module>
# ----> 1 df.set_index("Address", inplace=True)
#       2 df
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Address'] are in the columns"

# %%
df
# Out:
#                           City             State Country         Name  \
# Address
# 3666 21st St     San Francisco          CA 94114     USA      Madeira
# 735 Dolores St   San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St      San Francisco  California 94114     USA  Super River
# 3995 23rd St     San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St  San Francisco        California     USA      Sanchez
# 551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df.set_index("Name", inplace=True, drop=False)
df
# Out:
#                       City             State Country         Name  Employees
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %%
df.loc["Madeira":"Richvalley","Country":"Name"]
# Out:
#             Country         Name
# Name
# Madeira         USA      Madeira
# Bready Shop     USA  Bready Shop
# Super River     USA  Super River
# Ben's Shop      USA   Ben's Shop
# Sanchez         USA      Sanchez
# Richvalley      USA   Richvalley

# %%
df.loc[:,"Country"]
# Out:
# Name
# Madeira        USA
# Bready Shop    USA
# Super River    USA
# Ben's Shop     USA
# Sanchez        USA
# Richvalley     USA
# Name: Country, dtype: object

# %%
list(df.loc[:,"Country"])
# Out:
# ['USA', 'USA', 'USA', 'USA', 'USA', 'USA']

# %%
df
# Out:
#                       City             State Country         Name  Employees
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %%
df.iloc[1:3,1:3]
# Out:
#                         State Country
# Name
# Bready Shop          CA 94119     USA
# Super River  California 94114     USA

# %%
df.iloc[1,1:4]
# Out:
# State         CA 94119
# Country            USA
# Name       Bready Shop
# Name: Bready Shop, dtype: object

# %%
df["Name"]
# Out:
# Name
# Madeira            Madeira
# Bready Shop    Bready Shop
# Super River    Super River
# Ben's Shop      Ben's Shop
# Sanchez            Sanchez
# Richvalley      Richvalley
# Name: Name, dtype: object

# %%
df.drop("Employees", 1)
# Out:
#                       City             State Country         Name
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop
# Super River  San Francisco  California 94114     USA  Super River
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop
# Sanchez      San Francisco        California     USA      Sanchez
# Richvalley   San Francisco          CA 94114     USA   Richvalley

# %%
df
# Out:
#                       City             State Country         Name  Employees
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %%
help(pandas.DataFrame.drop)
# Out:
# Help on function drop in module pandas.core.frame:
#
# drop(self, labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
#     Drop specified labels from rows or columns.
#
#     Remove rows or columns by specifying label names and corresponding
#     axis, or by specifying directly index or column names. When using a
#     multi-index, labels on different levels can be removed by specifying
#     the level.
#
#     Parameters
#     ----------
#     labels : single label or list-like
#         Index or column labels to drop.
#     axis : {0 or 'index', 1 or 'columns'}, default 0
#         Whether to drop labels from the index (0 or 'index') or
#         columns (1 or 'columns').
#     index : single label or list-like
#         Alternative to specifying axis (``labels, axis=0``
#         is equivalent to ``index=labels``).
#
#         .. versionadded:: 0.21.0
#     columns : single label or list-like
# ...

# %%
df.drop("Sanchez", 0)
# Out:
#                       City             State Country         Name  Employees
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %%
df.drop(df.columns[0:3], 1)
# Out:
#                     Name  Employees
# Name
# Madeira          Madeira          8
# Bready Shop  Bready Shop         15
# Super River  Super River         25
# Ben's Shop    Ben's Shop         10
# Sanchez          Sanchez         12
# Richvalley    Richvalley         20

# %%
len(df.index)
# Out:
# 6

# %%
df
# Out:
#                       City             State Country         Name  Employees
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20

# %%
df["Continent"] = df.shape[0]*["America"]
df
# Out:
#                       City             State Country         Name  Employees  \
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20
#
#             Continent
# Name
# Madeira       America
# Bready Shop   America
# Super River   America
# Ben's Shop    America
# Sanchez       America
# Richvalley    America

# %%
df.shape[0]
# Out:
# 6

# %%
df
# Out:
#                       City             State Country         Name  Employees  \
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20
#
#             Continent
# Name
# Madeira       America
# Bready Shop   America
# Super River   America
# Ben's Shop    America
# Sanchez       America
# Richvalley    America

# %%
df["Region"] = "North " + df["Continent"]

# %%
df
# Out:
#                       City             State Country         Name  Employees  \
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20
#
#             Continent         Region
# Name
# Madeira       America  North America
# Bready Shop   America  North America
# Super River   America  North America
# Ben's Shop    America  North America
# Sanchez       America  North America
# Richvalley    America  North America

# %%
df.T
# Out:
# Name             Madeira    Bready Shop       Super River     Ben's Shop  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# Employees              8             15                25             10
# Continent        America        America           America        America
# Region     North America  North America     North America  North America
#
# Name             Sanchez     Richvalley
# City       San Francisco  San Francisco
# State         California       CA 94114
# Country              USA            USA
# Name             Sanchez     Richvalley
# Employees             12             20
# Continent        America        America
# Region     North America  North America

# %%
df_t = df.T
df_t["My Address"] = ['City', 'State', 'Country', 'Name', 'Employees', 'Continent', 'Region']
df_t
# Out:
# Name             Madeira    Bready Shop       Super River     Ben's Shop  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# Employees              8             15                25             10
# Continent        America        America           America        America
# Region     North America  North America     North America  North America
#
# Name             Sanchez     Richvalley My Address
# City       San Francisco  San Francisco       City
# State         California       CA 94114      State
# Country              USA            USA    Country
# Name             Sanchez     Richvalley       Name
# Employees             12             20  Employees
# Continent        America        America  Continent
# ...

# %%
df_t["Region 2"]="Occident"
df_t
# Out:
# Name             Madeira    Bready Shop       Super River     Ben's Shop  \
# City       San Francisco  San Francisco     San Francisco  San Francisco
# State           CA 94114       CA 94119  California 94114       CA 94114
# Country              USA            USA               USA            USA
# Name             Madeira    Bready Shop       Super River     Ben's Shop
# Employees              8             15                25             10
# Continent        America        America           America        America
# Region     North America  North America     North America  North America
#
# Name             Sanchez     Richvalley My Address  Region 2
# City       San Francisco  San Francisco       City  Occident
# State         California       CA 94114      State  Occident
# Country              USA            USA    Country  Occident
# Name             Sanchez     Richvalley       Name  Occident
# Employees             12             20  Employees  Occident
# ...

# %%
df_t.T
# Out:
#                       City             State   Country         Name  \
# Name
# Madeira      San Francisco          CA 94114       USA      Madeira
# Bready Shop  San Francisco          CA 94119       USA  Bready Shop
# Super River  San Francisco  California 94114       USA  Super River
# Ben's Shop   San Francisco          CA 94114       USA   Ben's Shop
# Sanchez      San Francisco        California       USA      Sanchez
# Richvalley   San Francisco          CA 94114       USA   Richvalley
# My Address            City             State   Country         Name
# Region 2          Occident          Occident  Occident     Occident
#
#              Employees  Continent         Region
# Name
# Madeira              8    America  North America
# Bready Shop         15    America  North America
# Super River         25    America  North America
# Ben's Shop          10    America  North America
# Sanchez             12    America  North America
# ...

# %%
df
# Out:
#                       City             State Country         Name  Employees  \
# Name
# Madeira      San Francisco          CA 94114     USA      Madeira          8
# Bready Shop  San Francisco          CA 94119     USA  Bready Shop         15
# Super River  San Francisco  California 94114     USA  Super River         25
# Ben's Shop   San Francisco          CA 94114     USA   Ben's Shop         10
# Sanchez      San Francisco        California     USA      Sanchez         12
# Richvalley   San Francisco          CA 94114     USA   Richvalley         20
#
#             Continent         Region
# Name
# Madeira       America  North America
# Bready Shop   America  North America
# Super River   America  North America
# Ben's Shop    America  North America
# Sanchez       America  North America
# Richvalley    America  North America

# %%
from geopy.geocoders import ArcGIS

# %%
nom = ArcGIS()

# %%
nom.geocode("3666 21st St, San Francisco, CA 94114")
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756632001957215, -122.42941101194798, 0.0))

# %%
import pandas
df = pandas.read_csv("supermarkets/supermarkets.csv")
df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df["Address"] = df["Address"] + ", " + df["City"] + ", " + df["State"] + ", " + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates
# ...

# %%
df.Coordinates[0]
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.756632001957215, -122.42941101194798, 0.0))

# %%
df["Latitude"] = df["Coordinates"].apply(lambda x: x.latitude if x != None else None)
df["Longitude"] = df["Coordinates"].apply(lambda x: x.longitude if x != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1  3666 21st St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 1   2  735 Dolores St, San Francisco, CA 94119, USA, ...  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, ...  San Francisco
# 3   4  3995 23rd St, San Francisco, CA 94114, USA, Sa...  San Francisco
# 4   5  1056 Sanchez St, San Francisco, California, US...  San Francisco
# 5   6  551 Alvarado St, San Francisco, CA 94114, USA,...  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
